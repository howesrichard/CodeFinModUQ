# %%
import pandas as pd
import random

# Create a list of 8 random numbers
numbers = [random.randint(1, 100) for i in range(8)]

# Create a pandas DataFrame from the list of numbers
df = pd.DataFrame({'Numbers': numbers})

# Print the DataFrame
print(df)
# Out:
#    Numbers
# 0       88
# 1       79
# 2       53
# 3       54
# 4       96
# 5       42
# 6       49
# 7       31

# %%
import pandas as pd
import random

def create_random_dataframe(n):
    # Create a list of n random numbers
    numbers = [random.randint(1, 100) for i in range(n)]

    # Create a pandas DataFrame from the list of numbers
    df = pd.DataFrame({'Numbers': numbers})

    # Return the DataFrame
    return df

df = create_random_dataframe(168)
print(df)
# Out:
#      Numbers
# 0         29
# 1         86
# 2         39
# 3         98
# 4         63
# ..       ...
# 163       47
# 164       47
# 165       42
# 166       24
# 167       52
#
# [168 rows x 1 columns]

# %%
# create a list of 168 random numbers
numbers = [random.randint(1, 100) for i in range(168)]
print(numbers)
# Out:
# [19, 52, 27, 52, 14, 34, 54, 72, 81, 38, 97, 94, 42, 91, 71, 71, 99, 88, 76, 54, 47, 56, 9, 69, 89, 89, 33, 75, 62, 9, 49, 56, 76, 61, 63, 49, 11, 19, 51, 34, 79, 99, 76, 30, 56, 70, 16, 31, 44, 28, 86, 33, 84, 15, 6, 27, 77, 34, 40, 36, 74, 65, 68, 72, 77, 71, 2, 25, 54, 30, 47, 51, 75, 98, 88, 13, 64, 13, 6, 4, 90, 58, 64, 32, 36, 82, 29, 53, 22, 99, 7, 67, 56, 43, 74, 70, 53, 60, 8, 52, 76, 39, 21, 40, 80, 48, 5, 24, 91, 90, 33, 49, 98, 85, 3, 95, 93, 32, 83, 9, 47, 75, 36, 5, 21, 64, 32, 43, 28, 4, 89, 2, 13, 49, 13, 14, 84, 27, 96, 76, 47, 42, 2, 88, 47, 9, 4, 33, 87, 9, 31, 56, 82, 61, 5, 28, 36, 83, 95, 61, 3, 88, 31, 66, 100, 52, 88, 73]

# %%
# use the random joke api to get and print a random joke
import requests
import json

url = 'https://official-joke-api.appspot.com/random_joke'
response = requests.get(url)
print(response)
print(response.text)
print(type(response.text))
print(json.loads(response.text))
print(type(json.loads(response.text)))
# Out:
# <Response [200]>
# {"type":"general","setup":"Who is the coolest Doctor in the hospital?","punchline":"The hip Doctor!","id":297}
# <class 'str'>
# {'type': 'general', 'setup': 'Who is the coolest Doctor in the hospital?', 'punchline': 'The hip Doctor!', 'id': 297}
# <class 'dict'>

# %%
# use the api.open-meteo.com api to get and print the current weather in London
import requests
import json

url = 'https://api.open-meteo.com/v1/forecast?latitude=51.5074&longitude=0.1278&hourly=temperature_2m'
